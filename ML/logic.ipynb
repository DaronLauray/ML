# %%
"""check for total_over_points, total_under_points to be equal<- this is the O/U line...
check for if total_over_won, and if total_under_won........................................................................
money_away_won will show if the away team won, money_home_won will show if home team won...................................
spread_away_won and spread_home_won will show who beat the spread..........................................................
spread_away_points and spread_home_points magnitude will show was underdog and overdog.....................................
overdog must win over the spread point, under dog mus lose by or win no more than the spread point.........................
game_date	away_team	home_team will reference the game and keep it in order
"""

# %%
import pandas as pd
import numpy as np


games= pd.read_csv("./Data/Games.csv")
games.sort_index(ascending=False)
# Out:
# C:\Users\15617\AppData\Local\Temp\ipykernel_18228\4062244234.py:5: DtypeWarning: Columns (0: gameSubtype, 1: gameSubLabel, 2: arenaName, 3: arenaCity, 4: arenaState, 5: officials) have mixed types. Specify dtype option on import or set low_memory=False.
#   games= pd.read_csv("./Data/Games.csv")
#          gameId      gameDateTimeEst  hometeamCity hometeamName  hometeamId  \
# 73193  24600052  1946-11-26 19:00:00  Philadelphia     Warriors  1610612744
# 73192  24600063  1946-11-30 19:00:00      New York       Knicks  1610612752
# 73191  24600076  1946-12-05 19:00:00  Philadelphia     Warriors  1610612744
# 73190  24600078  1946-12-07 19:00:00        Boston      Celtics  1610612738
# 73189  24600083  1946-12-08 19:00:00      New York       Knicks  1610612752
# ...         ...                  ...           ...          ...         ...
# 4      52500121  2026-04-14 22:00:00       Phoenix         Suns  1610612756
# ...
